# %%
# Import relevant libraries
import pandas as pd    
import numpy as np
import requests, os, zipfile, shutil, math
import rasterio as rio
import xarray as xr
import seaborn as sns
import geopandas as gpd
from pathlib import Path
from shapely.geometry import Point, box, LineString         
import matplotlib.pyplot as plt
from matplotlib_scalebar.scalebar import ScaleBar
from matplotlib.lines import Line2D
from matplotlib.patches import Patch
import rioxarray as rxr
from matplotlib.colors import ListedColormap, BoundaryNorm
from rasterio.io import MemoryFile
from rasterio.merge import merge
from rasterio.enums import Resampling
from shapely.ops import substring
from itertools import repeat
from rasterstats import zonal_stats
from rasterio.transform import rowcol
from rasterio.crs import CRS
from rasterio.warp import calculate_default_transform, reproject, Resampling

# %%
rail_segments = gpd.read_file("data/rail_segments.gpkg", layer = "rail_segments")

# %%
data_dir = Path("data")
data_dir.mkdir(parents = True, exist_ok = True)

eq_geojson = data_dir / "usgs_earthquakes_2021_2025_m3p5.geojson"
eq = gpd.read_file(eq_geojson)

faults = gpd.read_file(data_dir / "gem_active_faults.geojson")
